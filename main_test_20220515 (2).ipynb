# %% [markdown]
# ## main
#
# 할거
#
# - [x] segmentation load, write 빼기
# - [x] pixelate argument 통일
# - [x] 공통 함수?? - all -> fit
# - [x] ssh 권한
#
# 이번주
# - [ ] cp-vton 돌아가게하기
# - [ ] preprocess 정책 생각하기
#
# 다음주
# - [ ] segmentation 개선 - pixelate의 outline 안 밖을 0,255로 하면 되는 거 아닐까?
#
# 함께 to do
# - [ ] 공통 함수?? - plot??-- 형식 맞춰서 작성 필요
# - [ ] git-clone - https://ndb796.tistory.com/562
#
# 나중에
# - [ ] requirements

# %% [markdown]
# 있어야할 것들
# - method들
# - plot
# - all
# -

# %% [markdown]
# ### [temp] cpvton test.py
# - test_pairs.txt
#     - image : _0.jpg    ex) 000001_0.jpg
#     - cloth : _1.jpg    ex) 004325_1.jpg
# - filename_end rule
#     - ` _0.jpg ` : **image, image-parse, pose**
#     - ` _1.jpg ` : **cloth, cloth-mask, warp-cloth, warp-mask**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### [temp] cpvton test.py - main

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 12.1 MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5

# %%
# %cd drive/MyDrive/gan/PJ_01
# Out:
# /content/drive/MyDrive/gan/PJ_01

# %%
# !pwd # 폴더 이동 잘 됐는지 확인용
# Out:
# /content/drive/MyDrive/gan/PJ_01

# %%
! python test.py --name gmm --stage GMM --workers 4 --datamode test --data_list test_pairs.txt --checkpoint checkpoints/gmm_final.pth
# Out:
# Namespace(batch_size=4, checkpoint='checkpoints/gmm_final.pth', data_list='test_pairs.txt', datamode='test', dataroot='data', display_count=1, fine_height=256, fine_width=192, gpu_ids='', grid_size=5, name='gmm', radius=5, result_dir='result', shuffle=False, stage='GMM', tensorboard_dir='tensorboard', workers=4)
# Start to test stage: GMM, named: gmm!
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# initialization method [normal]
# initialization method [normal]
# data/test
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:4194: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# step:        1, time: 0.745
# step:        2, time: 0.633
# step:        3, time: 0.625
# step:        4, time: 0.629
# step:        5, time: 0.701
# step:        6, time: 0.154
# Finished test GMM, named: gmm!

# %%
! python test.py --name tom --stage TOM --workers 4 --datamode test --data_list test_pairs.txt --checkpoint checkpoints/tom_final.pth
# Out:
# Namespace(batch_size=4, checkpoint='checkpoints/tom_final.pth', data_list='test_pairs.txt', datamode='test', dataroot='data', display_count=1, fine_height=256, fine_width=192, gpu_ids='', grid_size=5, name='tom', radius=5, result_dir='result', shuffle=False, stage='TOM', tensorboard_dir='tensorboard', workers=4)
# Start to test stage: TOM, named: tom!
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Dataset size: 00021!
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1933: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# step:        1, time: 1.223
# step:        2, time: 0.795
# step:        3, time: 0.833
# step:        4, time: 1.200
# step:        5, time: 0.760
# step:        6, time: 0.197
# Finished test TOM, named: tom!

# %%
# !pip install tensorboardX
# !pip install opencv-python
# !pip install git+https://github.com/sedthh/pyxelate.git
# from skimage import io

# %% [markdown]
# # [main] RUN

# %%
# %run model.py
