# %% [markdown]
# ## SSH 키를 이용하여 깃 프로젝트 연동하기
# - 최초 1번 실행

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/gan/PJ_01_local
# Out:
# /content/drive/MyDrive/gan/PJ_01_local

# %%
# ssh 키 생성
# /root/.ssh/ 폴더에 id_rsa.pub(공개키)와 id_rsa(개인키) 파일이 생성된다.

# 중간중간 뜨는건 아무것도 입력하지 않고 엔터를 누르면 된다!

# !ssh-keygen
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa.
# Your public key has been saved in /root/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:02fdrU1xEUAKnpeVP84DaiuUjUiYqQKFsKAALBvNz1A root@f89c57f95313
# The key's randomart image is:
# +---[RSA 2048]----+
# |O+ .E    .  .+oo.|
# |Bo=     . o +.  .|
# |++ +  +  o +  ...|
# |o   o+ . ..  o ++|
# |.   . . S = + = =|
# | . .   . = *   B |
# |  .     . . . . o|
# |         . .     |
# |          .      |
# +----[SHA256]-----+

# %%
# 공개키를 복사하여 깃허브 ssh에 등록
! cat ~/.ssh/id_rsa.pub
# Out:
# ssh-rsa  root@f89c57f95313

# %%
# 알려진 호스트(known hosts)에 GitHub 호스트 주소 넣기 
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-406cafbd

# %%
# 깃 저장소를 클론할 폴더로 이동
# %cd /content/drive/MyDrive/gan/PJ_01_working
# Out:
# /content/drive/MyDrive/gan/PJ_01_working

# %%
# private repository를 클론
# !git clone git@github.com:shyun46/PJ_01.git
# Out:
# Cloning into 'PJ_01'...
# Warning: Permanently added the RSA host key for IP address '140.82.113.3' to the list of known hosts.
# remote: Enumerating objects: 569, done.
# remote: Counting objects: 100% (404/404), done.
# remote: Compressing objects: 100% (328/328), done.
# remote: Total 569 (delta 128), reused 336 (delta 66), pack-reused 165
# Receiving objects: 100% (569/569), 171.74 MiB | 11.20 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# Checking out files: 100% (165/165), done.

# %%
# !git init
# %cd /content/drive/MyDrive/gan/PJ_01_working/PJ_01
# Out:
# /content/drive/MyDrive/gan/PJ_01_working/PJ_01

# %%
# 본인 브랜치 생성
! git branch feature/olive46

# %%
# 생성한 브랜치 push
! git push --set-upstream origin feature/olive46
# Out:
# Warning: Permanently added the RSA host key for IP address '140.82.112.4' to the list of known hosts.
# Total 0 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'feature/olive46' on GitHub by visiting:
# remote:      https://github.com/shyun46/PJ_01/pull/new/feature/olive46
# remote:
# To github.com:shyun46/PJ_01.git
#  * [new branch]      feature/olive46 -> feature/olive46
# Branch 'feature/olive46' set up to track remote branch 'feature/olive46' from 'origin'.

# %% [markdown]
# ## 프로젝트에 PUSH 하기
# - 파일 변경 시 항상 실행

# %%
# 1. 깃 프로젝트가 담긴 폴더로 이동
# %cd /content/drive/MyDrive/gan/PJ_01_working/PJ_01
# Out:
# /content/drive/MyDrive/gan/PJ_01_working/PJ_01

# %%
# 2. 알려진 호스트(known hosts)에 GitHub 호스트 주소 넣기 (매번 해주는게 맞나?)
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-406cafbd

# %%
# 3. 계정정보 입력
! git config --global user.email "olive46@gmail.com"
! git config --global user.name "olive46"

# %%
# 4. 본인 브랜치로 이동
! git checkout feature/olive46
! git branch
# Out:
# Switched to branch 'feature/olive46'
# Your branch is up to date with 'origin/feature/olive46'.
# * feature/olive46
#   main

# %%
# 5. 파일 변경 후 PUSH
f = open('test.txt', 'w')

f.write("TEST")

f.close()

# %%
! git add test.txt

# %%
! git commit -m "olive46_test"
# Out:
# [feature/olive46 bb1b616] olive46_test
#  1 file changed, 1 insertion(+)
#  create mode 100644 test.txt

# %%
! git push
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 264 bytes | 88.00 KiB/s, done.
# Total 3 (delta 1), reused 1 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To github.com:shyun46/PJ_01.git
#    262be0f..bb1b616  feature/olive46 -> feature/olive46

# %% [markdown]
# ## 프로젝트에 작업하기 (model.py 실행)

# %%
# !pip install tensorboardX
# !pip install git+https://github.com/sedthh/pyxelate.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 33.1 MB/s
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/sedthh/pyxelate.git
#   Cloning https://github.com/sedthh/pyxelate.git to /tmp/pip-req-build-vw2o8zo9
#   Running command git clone -q https://github.com/sedthh/pyxelate.git /tmp/pip-req-build-vw2o8zo9
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.7/dist-packages (from pyxelate==2.1.1) (1.0.2)
# Collecting scikit-image>=0.19.1
#   Downloading scikit_image-0.19.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (13.5 MB)
#      |████████████████████████████████| 13.5 MB 26.3 MB/s
# Collecting numba>=0.53.1
#   Downloading numba-0.55.2-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 57.6 MB/s
# Requirement already satisfied: numpy<1.23,>=1.18 in /usr/local/lib/python3.7/dist-packages (from numba>=0.53.1->pyxelate==2.1.1) (1.21.6)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 1.2 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.53.1->pyxelate==2.1.1) (57.4.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.19.1->pyxelate==2.1.1) (2.6.3)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.19.1->pyxelate==2.1.1) (2.4.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.19.1->pyxelate==2.1.1) (7.1.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.19.1->pyxelate==2.1.1) (2021.11.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.19.1->pyxelate==2.1.1) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.19.1->pyxelate==2.1.1) (21.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.19.1->pyxelate==2.1.1) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->scikit-image>=0.19.1->pyxelate==2.1.1) (3.0.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->pyxelate==2.1.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->pyxelate==2.1.1) (3.1.0)
# Building wheels for collected packages: pyxelate
#   Building wheel for pyxelate (setup.py) ... done
#   Created wheel for pyxelate: filename=pyxelate-2.1.1-py3-none-any.whl size=14206 sha256=b75c83e6c4f599b8fad5fb6d7d025aa08eb1bd04a2abd6554c118e2b8332bb99
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zteyqchs/wheels/2e/33/10/b5be4d740bba2dc4d3311bb6c0047214db53a7098bd88051dc
# Successfully built pyxelate
# Installing collected packages: llvmlite, scikit-image, numba, pyxelate
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.18.3
#     Uninstalling scikit-image-0.18.3:
#       Successfully uninstalled scikit-image-0.18.3
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed llvmlite-0.38.1 numba-0.55.2 pyxelate-2.1.1 scikit-image-0.19.3

# %%
# 전체 돌리기 - 세부 로그 안뜸
# %run model.py
# Out:
# ** PIPELINE 1 (mode = live) ___________________________________________________________________________________________
# ** RUN COMMAND SCRIPT - python step/test.py --name gmm --stage GMM --workers 4 --datamode test --data_list test_pairs.txt --checkpoint checkpoints/gmm/gmm_final.pth
#
#    [STEP : Tryon, METHOD : 1, VERSION : 0.0]  : cp-vton 논문의 pretrained checkpoint 사용한 방법
#
#       |-> log :
#       |
# ** RUN COMMAND SCRIPT - python step/test.py --name tom --stage TOM --workers 4 --datamode test --data_list test_pairs.txt --checkpoint checkpoints/tom/tom_final.pth

# %%
# 각각 돌리기 01 - gmm
! python step/test.py --name gmm --stage GMM --workers 4 --datamode test --data_list test_pairs.txt --checkpoint checkpoints/gmm/gmm_final.pth
# Out:
# Namespace(batch_size=4, checkpoint='checkpoints/gmm/gmm_final.pth', data_list='test_pairs.txt', datamode='test', dataroot='data', display_count=1, fine_height=256, fine_width=192, gpu_ids='', grid_size=5, name='gmm', radius=5, result_dir='result', shuffle=False, stage='GMM', tensorboard_dir='tensorboard', workers=4)
# Start to test stage: GMM, named: gmm!
# *** train_dataset is DONE! ***
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# *** train_loader is DONE! ***
# *** visualization code is DONE! ***
# c (256, 192, 3)
# c (256, 192, 3)
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# initialization method [normal]
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# initialization method [normal]
# *** GMM model is Loaded! ***
# c (256, 192, 3)
# c (256, 192, 3)
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# c (256, 192, 3)
# c (256, 192, 3)
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:4194: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# step:        1, time: 0.657
# step:        2, time: 0.517
# step:        3, time: 0.453
# step:        4, time: 0.507
# step:        5, time: 0.457
# step:        6, time: 0.139
# *** test_gmm is DONE! ***
# Finished test GMM, named: gmm!

# %%
# 각각 돌리기 02 - tom
! python step/test.py --name tom --stage TOM --workers 4 --datamode test --data_list test_pairs.txt --checkpoint checkpoints/tom/tom_final.pth
# Out:
# Namespace(batch_size=4, checkpoint='checkpoints/tom/tom_final.pth', data_list='test_pairs.txt', datamode='test', dataroot='data', display_count=1, fine_height=256, fine_width=192, gpu_ids='', grid_size=5, name='tom', radius=5, result_dir='result', shuffle=False, stage='TOM', tensorboard_dir='tensorboard', workers=4)
# Start to test stage: TOM, named: tom!
# *** train_dataset is DONE! ***
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# *** train_loader is DONE! ***
# *** visualization code is DONE! ***
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# *** TOM model is Loaded! ***
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# Dataset size: 00021!
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# im <class 'torch.Tensor'> torch.Size([3, 256, 192])
# im_c <class 'torch.Tensor'> torch.Size([3, 256, 192])
# pcm <class 'torch.Tensor'> torch.Size([256, 192])
# im_h <class 'torch.Tensor'> torch.Size([3, 256, 192])
# phead <class 'torch.Tensor'> torch.Size([256, 192])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1933: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# step:        1, time: 0.676
# step:        2, time: 0.594
# step:        3, time: 0.616
# step:        4, time: 0.608
# step:        5, time: 0.613
# step:        6, time: 0.177
# *** test_tom is DONE! ***
# Finished test TOM, named: tom!
