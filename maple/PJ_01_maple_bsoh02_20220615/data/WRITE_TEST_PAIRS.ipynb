# %%
# %cd /content/drive/MyDrive/AI/GAN_Clothes_item/CP-VTON_sohyeon/CP-VTON_customdata/data

# 경로 맞춰서 이동 필요
# Out:
# /content/drive/MyDrive/AI/GAN_Clothes_item/CP-VTON_sohyeon/CP-VTON_customdata/data

# %%
f = open('test_pairs.txt', 'w')

f.write("\n000001_0.jpg 000009_1.jpg")

f.close()
